# %%
# Import dependencies
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# List all files to be combined
file_compliation = ['data/202107.csv', 'data/202108.csv', 'data/202109.csv', 'data/202110.csv', 'data/202111.csv', 'data/202112.csv',
    'data/202201.csv', 'data/202202.csv', 'data/202203.csv', 'data/202204.csv', 'data/202205.csv', 'data/202206.csv', 'data/202207.csv', 'data/202208.csv', 'data/202209.csv', 'data/202210.csv', 'data/202211.csv', 'data/202212.csv',
        'data/202301.csv', 'data/202302.csv', 'data/202303.csv']

# Create an empty list to store each df
df_list = []

# Loop
for file in file_compliation:
    df = pd.read_csv(file)
    df_list.append(df)

# Concatenate all dataframes into one
# https://www.geeksforgeeks.org/how-to-concatenate-two-or-more-pandas-dataframes/
df = pd.concat(df_list)

df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      C9446233AFAB8896   classic_bike  2021-07-15 19:27:25
# 1      0C3D69370BE39992  electric_bike  2021-07-22 06:41:54
# 2      3B0390B706281176   classic_bike  2021-07-19 06:36:13
# 3      9AFBC07247ABE507   classic_bike  2021-07-08 06:33:45
# 4      ADB073F7FFC372D3   classic_bike  2021-07-21 07:33:49
# ...                 ...            ...                  ...
# 63067  BF0032DA4A305161   classic_bike  2023-03-19 16:25:24
# 63068  32172F9BEF8D56A2   classic_bike  2023-03-22 16:14:15
# 63069  6FCF0C7C1E254341  electric_bike  2023-03-19 02:16:02
# 63070  34DFBEB02424B55E  electric_bike  2023-03-30 20:09:24
# 63071  A235AD010540ACA2   classic_bike  2023-03-17 17:53:28
#
#                   ended_at                 start_station_name  \
# 0      2021-07-15 19:27:35                     Journal Square
# 1      2021-07-22 06:42:03                     Journal Square
# ...

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
## Formatting

# Correcting datatypes
df['started_at'] = pd.to_datetime(df['started_at'], format = "%Y-%m-%d %H:%M:%S")
df['ended_at'] = pd.to_datetime(df['ended_at'], format = "%Y-%m-%d %H:%M:%S")

# Check 
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# dtype: object

# %%
## Formatting

# Lat/Lon decimals
df['start_lat'] = df['start_lat'].round(decimals=5)
df['start_lng'] = df['start_lng'].round(decimals=5)
df['end_lat'] = df['end_lat'].round(decimals=5)
df['end_lng'] = df['end_lng'].round(decimals=5)

# Check
df
# Out:
#                 ride_id  rideable_type          started_at  \
# 0      C9446233AFAB8896   classic_bike 2021-07-15 19:27:25
# 1      0C3D69370BE39992  electric_bike 2021-07-22 06:41:54
# 2      3B0390B706281176   classic_bike 2021-07-19 06:36:13
# 3      9AFBC07247ABE507   classic_bike 2021-07-08 06:33:45
# 4      ADB073F7FFC372D3   classic_bike 2021-07-21 07:33:49
# ...                 ...            ...                 ...
# 63067  BF0032DA4A305161   classic_bike 2023-03-19 16:25:24
# 63068  32172F9BEF8D56A2   classic_bike 2023-03-22 16:14:15
# 63069  6FCF0C7C1E254341  electric_bike 2023-03-19 02:16:02
# 63070  34DFBEB02424B55E  electric_bike 2023-03-30 20:09:24
# 63071  A235AD010540ACA2   classic_bike 2023-03-17 17:53:28
#
#                  ended_at                 start_station_name start_station_id  \
# 0     2021-07-15 19:27:35                     Journal Square            JC103
# 1     2021-07-22 06:42:03                     Journal Square            JC103
# ...

# %%
# Save df to csv file
df.to_csv('data/citibike.csv', index = False)
